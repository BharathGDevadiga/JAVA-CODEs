# %%
import numpy as np
import pandas as pd

# %%
data=pd.Series([0.25,0.5,0.75,1.0])
data
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %%
data.values
# Out:
# array([0.25, 0.5 , 0.75, 1.  ])

# %%
data[1]
# Out:
# np.float64(0.5)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4, step=1)
